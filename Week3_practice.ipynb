# %%
#練習1
s="因葉益成（已歿）積欠伊賭債新臺幣（下同）60萬元，交付楊清弦美製貝瑞塔手槍1支、美製史密斯手槍1支、制式口徑9mm子彈26顆 、土造金屬子彈1顆、仿美國COLT廠M1911A1型半自動手槍1支、口徑0.45吋制式子彈1顆，而未經許可而持有之。"
l=s.split("，")
print(l)
del l[0]
del l[1]
print(l)

ll=l[0].split("、")
print(ll)

del ll[0]
print(ll)
ll.insert(0,"美製貝瑞塔手槍1支")
print(ll)
# Out:
# ['因葉益成（已歿）積欠伊賭債新臺幣（下同）60萬元', '交付楊清弦美製貝瑞塔手槍1支、美製史密斯手槍1支、制式口徑9mm子彈26顆 、土造金屬子彈1顆、仿美國COLT廠M1911A1型半自動手槍1支、口徑0.45吋制式子彈1顆', '而未經許可而持有之。']
# ['交付楊清弦美製貝瑞塔手槍1支、美製史密斯手槍1支、制式口徑9mm子彈26顆 、土造金屬子彈1顆、仿美國COLT廠M1911A1型半自動手槍1支、口徑0.45吋制式子彈1顆']
# ['交付楊清弦美製貝瑞塔手槍1支', '美製史密斯手槍1支', '制式口徑9mm子彈26顆 ', '土造金屬子彈1顆', '仿美國COLT廠M1911A1型半自動手槍1支', '口徑0.45吋制式子彈1顆']
# ['美製史密斯手槍1支', '制式口徑9mm子彈26顆 ', '土造金屬子彈1顆', '仿美國COLT廠M1911A1型半自動手槍1支', '口徑0.45吋制式子彈1顆']
# ['美製貝瑞塔手槍1支', '美製史密斯手槍1支', '制式口徑9mm子彈26顆 ', '土造金屬子彈1顆', '仿美國COLT廠M1911A1型半自動手槍1支', '口徑0.45吋制式子彈1顆']

# %%
#練習2
tuple1=("最高法院民事判例","最高法院刑事判例","行政法院判例","大法官解釋")
tuple2=(7,3,5,4)
t=tuple1[:3]
print(t)

zip12=zip(t,tuple2)
print(list(zip12))
# Out:
# ('最高法院民事判例', '最高法院刑事判例', '行政法院判例')
# [('最高法院民事判例', 7), ('最高法院刑事判例', 3), ('行政法院判例', 5)]

# %%
#練習3
A={"有期徒刑","沒收","罰金"}
B={"無期徒刑","罰金","褫奪公權"}
print(A|B)
print(B-A)
print(A&B)
print("罰金" in A)
print("罰金" in B)
# Out:
# {'無期徒刑', '褫奪公權', '有期徒刑', '沒收', '罰金'}
# {'無期徒刑', '褫奪公權'}
# {'罰金'}
# True
# True

# %%
#練習4
d={"刑事訴訟法":["第159條之4","第159條之5","第159條之1","第267條","第299條第1項","第302條第1款"
],"中華民國憲法":["第11條","第38條第1項第1款","第42條第3項","第55條""第56條","第57條","第59條"]}
l1=list(d.keys())
print(l1)
l2=list(d.values())
print(l2)
print(d["刑事訴訟法"][3])
d["中華民國憲法"]=["第11條","第38條第1項第1款","第42條第3項","第55條""第56條","第57條","第59條","第62條"]
print(d)
# Out:
# ['刑事訴訟法', '中華民國憲法']
# [['第159條之4', '第159條之5', '第159條之1', '第267條', '第299條第1項', '第302條第1款'], ['第11條', '第38條第1項第1款', '第42條第3項', '第55條第56條', '第57條', '第59條']]
# 第267條
# {'刑事訴訟法': ['第159條之4', '第159條之5', '第159條之1', '第267條', '第299條第1項', '第302條第1款'], '中華民國憲法': ['第11條', '第38條第1項第1款', '第42條第3項', '第55條第56條', '第57條', '第59條', '第62條']}
# {'刑事訴訟法': ['第159條之4', '第159條之5', '第159條之1', '第267條', '第299條第1項', '第302條第1款'], '中華民國憲法': ['第11條', '第38條第1項第1款', '第42條第3項', '第55條第56條', '第57條', '第59條', '第62條']}
